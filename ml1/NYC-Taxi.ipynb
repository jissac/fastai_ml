# %% [markdown]
# # NYC Taxi Trips
# https://www.kaggle.com/c/nyc-taxi-trip-duration/data

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib.pyplot as plt
import sys
import os
import fastai
from fastai.structured import *
import pandas as pd
import numpy as np
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor
from IPython.display import display
from sklearn import metrics
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %% [markdown]
# ### Load Data

# %% [markdown]
# #### Training Set

# %%
df_raw = pd.read_csv('./data/nyc-taxi/train.csv',parse_dates=['pickup_datetime','dropoff_datetime'])

# %%
df_raw.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# trip_duration                  int64
# dtype: object

# %%
len(df_raw)
# Out:
# 1458644

# %%
len(df_raw.columns)
# Out:
# 11

# %%
df_summ = DataFrameSummary(df_raw)
display_all(df_summ.summary())
# Out:
#                    id    vendor_id pickup_datetime dropoff_datetime  \
# count             NaN  1.45864e+06             NaN              NaN
# mean              NaN      1.53495             NaN              NaN
# std               NaN     0.498777             NaN              NaN
# min               NaN            1             NaN              NaN
# 25%               NaN            1             NaN              NaN
# 50%               NaN            2             NaN              NaN
# 75%               NaN            2             NaN              NaN
# max               NaN            2             NaN              NaN
# counts        1458644      1458644         1458644          1458644
# uniques       1458644            2         1380222          1380377
# missing             0            0               0                0
# missing_perc       0%           0%              0%               0%
# types          unique         bool            date             date
#
#              passenger_count pickup_longitude pickup_latitude  \
# count            1.45864e+06      1.45864e+06     1.45864e+06
# mean                 1.66453         -73.9735         40.7509
# std                  1.31424        0.0709019       0.0328812
# min                        0         -121.933         34.3597
# 25%                        1         -73.9919         40.7373
# 50%                        1         -73.9817         40.7541
# 75%                        2         -73.9673         40.7684
# max                        9         -61.3355         51.8811
# counts               1458644          1458644         1458644
# uniques                   10            23047           45245
# missing                    0                0               0
# missing_perc              0%               0%              0%
# types                numeric          numeric         numeric
#
#              dropoff_longitude dropoff_latitude store_and_fwd_flag  \
# count              1.45864e+06      1.45864e+06                NaN
# mean                  -73.9734          40.7518                NaN
# std                  0.0706433        0.0358906                NaN
# min                   -121.933          32.1811                NaN
# 25%                   -73.9913          40.7359                NaN
# 50%                   -73.9798          40.7545                NaN
# 75%                    -73.963          40.7698                NaN
# max                   -61.3355           43.921                NaN
# counts                 1458644          1458644            1458644
# uniques                  33821            62519                  2
# missing                      0                0                  0
# missing_perc                0%               0%                 0%
# types                  numeric          numeric               bool
#
#              trip_duration
# count          1.45864e+06
# mean               959.492
# std                5237.43
# min                      1
# 25%                    397
# 50%                    662
# 75%                   1075
# max            3.52628e+06
# counts             1458644
# uniques               7417
# missing                  0
# missing_perc            0%
# types              numeric

# %%
types = {'id': 'unit32', 'vendor_id': '', 'pickup_datetime', 'dropoff_datetime',
       'passenger_count', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
       'trip_duration'}

# %%
df_raw[['pickup_datetime','dropoff_datetime']]
# Out:
#             pickup_datetime    dropoff_datetime
# 0       2016-03-14 17:24:55 2016-03-14 17:32:30
# 1       2016-06-12 00:43:35 2016-06-12 00:54:38
# 2       2016-01-19 11:35:24 2016-01-19 12:10:48
# 3       2016-04-06 19:32:31 2016-04-06 19:39:40
# 4       2016-03-26 13:30:55 2016-03-26 13:38:10
# ...                     ...                 ...
# 1458639 2016-04-08 13:31:04 2016-04-08 13:44:02
# 1458640 2016-01-10 07:35:15 2016-01-10 07:46:10
# 1458641 2016-04-22 06:57:41 2016-04-22 07:10:25
# 1458642 2016-01-05 15:56:26 2016-01-05 16:02:39
# 1458643 2016-04-05 14:44:25 2016-04-05 14:47:43
#
# [1458644 rows x 2 columns]

# %%
df_raw.describe()
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  1.458644e+06     1.458644e+06      1.458644e+06     1.458644e+06
# mean   1.534950e+00     1.664530e+00     -7.397349e+01     4.075092e+01
# std    4.987772e-01     1.314242e+00      7.090186e-02     3.288119e-02
# min    1.000000e+00     0.000000e+00     -1.219333e+02     3.435970e+01
# 25%    1.000000e+00     1.000000e+00     -7.399187e+01     4.073735e+01
# 50%    2.000000e+00     1.000000e+00     -7.398174e+01     4.075410e+01
# 75%    2.000000e+00     2.000000e+00     -7.396733e+01     4.076836e+01
# max    2.000000e+00     9.000000e+00     -6.133553e+01     5.188108e+01
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count       1.458644e+06      1.458644e+06   1.458644e+06
# mean       -7.397342e+01      4.075180e+01   9.594923e+02
# std         7.064327e-02      3.589056e-02   5.237432e+03
# min        -1.219333e+02      3.218114e+01   1.000000e+00
# 25%        -7.399133e+01      4.073588e+01   3.970000e+02
# 50%        -7.397975e+01      4.075452e+01   6.620000e+02
# 75%        -7.396301e+01      4.076981e+01   1.075000e+03
# max        -6.133553e+01      4.392103e+01   3.526282e+06

# %% [markdown]
# #### Test Set

# %%
df_test = pd.read_csv('./data/nyc-taxi/test.csv')

# %%
df_test_summ = DataFrameSummary(df_test)
display_all(df_test_summ .summary())
# Out:
#                   id vendor_id pickup_datetime passenger_count  \
# count            NaN    625134             NaN          625134
# mean             NaN   1.53488             NaN         1.66177
# std              NaN  0.498782             NaN         1.31129
# min              NaN         1             NaN               0
# 25%              NaN         1             NaN               1
# 50%              NaN         2             NaN               1
# 75%              NaN         2             NaN               2
# max              NaN         2             NaN               9
# counts        625134    625134          625134          625134
# uniques       625134         2          610581               8
# missing            0         0               0               0
# missing_perc      0%        0%              0%              0%
# types         unique      bool     categorical         numeric
#
#              pickup_longitude pickup_latitude dropoff_longitude  \
# count                  625134          625134            625134
# mean                 -73.9736         40.7509          -73.9735
# std                  0.073389       0.0298478         0.0725649
# min                  -121.933         37.3896          -121.933
# 25%                  -73.9919         40.7374          -73.9913
# 50%                  -73.9817         40.7541          -73.9798
# 75%                  -73.9674         40.7684           -73.963
# max                  -69.2489         42.8149          -67.4968
# counts                 625134          625134            625134
# uniques                 18926           38408             26476
# missing                     0               0                 0
# missing_perc               0%              0%                0%
# types                 numeric         numeric           numeric
#
#              dropoff_latitude store_and_fwd_flag
# count                  625134                NaN
# mean                  40.7518                NaN
# std                 0.0358239                NaN
# min                   36.6013                NaN
# 25%                    40.736                NaN
# 50%                   40.7545                NaN
# 75%                   40.7699                NaN
# max                   48.8576                NaN
# counts                 625134             625134
# uniques                 51439                  2
# missing                     0                  0
# missing_perc               0%                 0%
# types                 numeric               bool

# %%
df_test.columns # missing dropoff time and trip length
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'passenger_count',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'store_and_fwd_flag'],
#       dtype='object')

# %% [markdown]
# ### Cleaning and Transforms

# %% [markdown]
# #### Remove cols from training set to match test set

# %%
df_raw = df_raw.drop(columns=['dropoff_datetime'])

# %%
df_raw.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'passenger_count',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'store_and_fwd_flag', 'trip_duration'],
#       dtype='object')

# %% [markdown]
# #### Add Datepart

# %%
# %time add_datepart(df_raw,'pickup_datetime')
# %time add_datepart(df_test,'pickup_datetime')
# Out:
# CPU times: user 1.52 s, sys: 190 ms, total: 1.71 s
# Wall time: 1.87 s
# CPU times: user 716 ms, sys: 114 ms, total: 831 ms
# Wall time: 853 ms

# %%
display_all(df_raw)
# Out:
#                 id  vendor_id  passenger_count  pickup_longitude  \
# 0        id2875421          2                1        -73.982155
# 1        id2377394          1                1        -73.980415
# 2        id3858529          2                1        -73.979027
# 3        id3504673          2                1        -74.010040
# 4        id2181028          2                1        -73.973053
# ...            ...        ...              ...               ...
# 1458639  id2376096          2                4        -73.982201
# 1458640  id1049543          1                1        -74.000946
# 1458641  id2304944          2                1        -73.959129
# 1458642  id2714485          1                1        -73.982079
# 1458643  id1209952          1                1        -73.979538
#
#          pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0              40.767937         -73.964630         40.765602
# 1              40.738564         -73.999481         40.731152
# 2              40.763939         -74.005333         40.710087
# 3              40.719971         -74.012268         40.706718
# 4              40.793209         -73.972923         40.782520
# ...                  ...                ...               ...
# 1458639        40.745522         -73.994911         40.740170
# 1458640        40.747379         -73.970184         40.796547
# 1458641        40.768799         -74.004433         40.707371
# 1458642        40.749062         -73.974632         40.757107
# 1458643        40.781750         -73.972809         40.790585
#
#         store_and_fwd_flag  trip_duration  pickup_datetimeYear  \
# 0                        N            455                 2016
# 1                        N            663                 2016
# 2                        N           2124                 2016
# 3                        N            429                 2016
# 4                        N            435                 2016
# ...                    ...            ...                  ...
# 1458639                  N            778                 2016
# 1458640                  N            655                 2016
# 1458641                  N            764                 2016
# 1458642                  N            373                 2016
# 1458643                  N            198                 2016
#
#          pickup_datetimeMonth  pickup_datetimeWeek  pickup_datetimeDay  \
# 0                           3                   11                  14
# 1                           6                   23                  12
# 2                           1                    3                  19
# 3                           4                   14                   6
# 4                           3                   12                  26
# ...                       ...                  ...                 ...
# 1458639                     4                   14                   8
# 1458640                     1                    1                  10
# 1458641                     4                   16                  22
# 1458642                     1                    1                   5
# 1458643                     4                   14                   5
#
#          pickup_datetimeDayofweek  pickup_datetimeDayofyear  \
# 0                               0                        74
# 1                               6                       164
# 2                               1                        19
# 3                               2                        97
# 4                               5                        86
# ...                           ...                       ...
# 1458639                         4                        99
# 1458640                         6                        10
# 1458641                         4                       113
# 1458642                         1                         5
# 1458643                         1                        96
#
#          pickup_datetimeIs_month_end  pickup_datetimeIs_month_start  \
# 0                              False                          False
# 1                              False                          False
# 2                              False                          False
# 3                              False                          False
# 4                              False                          False
# ...                              ...                            ...
# 1458639                        False                          False
# 1458640                        False                          False
# 1458641                        False                          False
# 1458642                        False                          False
# 1458643                        False                          False
#
#          pickup_datetimeIs_quarter_end  pickup_datetimeIs_quarter_start  \
# 0                                False                            False
# 1                                False                            False
# 2                                False                            False
# 3                                False                            False
# 4                                False                            False
# ...                                ...                              ...
# 1458639                          False                            False
# 1458640                          False                            False
# 1458641                          False                            False
# 1458642                          False                            False
# 1458643                          False                            False
#
#          pickup_datetimeIs_year_end  pickup_datetimeIs_year_start  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
# ...                             ...                           ...
# 1458639                       False                         False
# 1458640                       False                         False
# 1458641                       False                         False
# 1458642                       False                         False
# 1458643                       False                         False
#
#          pickup_datetimeElapsed
# 0                    1457976295
# 1                    1465692215
# 2                    1453203324
# 3                    1459971151
# 4                    1458999055
# ...                         ...
# 1458639              1460122264
# 1458640              1452411315
# 1458641              1461308261
# 1458642              1452009386
# 1458643              1459867465
#
# [1458644 rows x 22 columns]

# %% [markdown]
# #### Modify dependent variable to match evaluation metric

# %%
df_raw.trip_duration
# Out:
# 0           455
# 1           663
# 2          2124
# 3           429
# 4           435
#            ...
# 1458639     778
# 1458640     655
# 1458641     764
# 1458642     373
# 1458643     198
# Name: trip_duration, Length: 1458644, dtype: int64

# %%
df_raw.trip_duration = np.log(df_raw.trip_duration)

# %%
df_raw.trip_duration
# Out:
# 0          6.120297
# 1          6.496775
# 2          7.661056
# 3          6.061457
# 4          6.075346
#              ...
# 1458639    6.656727
# 1458640    6.484635
# 1458641    6.638568
# 1458642    5.921578
# 1458643    5.288267
# Name: trip_duration, Length: 1458644, dtype: float64

# %% [markdown]
# #### split raw df into train and val sets, val set contains most recent values

# %%
def split_vals(a,n):
    return a[:n].copy(),a[n:].copy()

# %%
n_valid = len(df_test)
n_train = len(df_raw)-n_valid
training_set, val_set = split_vals(df_raw,n_train)
training_set.shape, val_set.shape
# Out:
# ((833510, 22), (625134, 22))

# %% [markdown]
# #### Separate response variables in df_raw and convert everything to numeric

# %%
# %time
X_train, y_train, _ = proc_df(training_set,y_fld='trip_duration')
X_valid, y_valid, _ = proc_df(val_set,y_fld='trip_duration')
X_test, _, _ = proc_df(df_test)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.34 µs

# %%
X_train
# Out:
#             id  vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# 0       599533          2                1        -73.982155        40.767937
# 1       495717          1                1        -73.980415        40.738564
# 2       803903          2                1        -73.979027        40.763939
# 3       730611          2                1        -74.010040        40.719971
# 4       454722          2                1        -73.973053        40.793209
# ...        ...        ...              ...               ...              ...
# 833505  663114          1                1        -73.972450        40.764912
# 833506  255389          1                1        -73.959084        40.763596
# 833507   57563          2                1        -73.895889        40.740517
# 833508  135462          2                1        -73.995674        40.764587
# 833509  394727          1                1        -73.978668        40.751038
#
#         dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 0              -73.964630         40.765602                   1
# 1              -73.999481         40.731152                   1
# 2              -74.005333         40.710087                   1
# 3              -74.012268         40.706718                   1
# 4              -73.972923         40.782520                   1
# ...                   ...               ...                 ...
# 833505         -73.991188         40.739456                   1
# 833506         -74.008049         40.738941                   1
# 833507         -73.923767         40.743988                   1
# 833508         -73.994263         40.759308                   1
# 833509         -73.987740         40.744072                   1
#
#         pickup_datetimeYear  pickup_datetimeMonth  ...  pickup_datetimeDay  \
# 0                      2016                     3  ...                  14
# 1                      2016                     6  ...                  12
# 2                      2016                     1  ...                  19
# 3                      2016                     4  ...                   6
# 4                      2016                     3  ...                  26
# ...                     ...                   ...  ...                 ...
# 833505                 2016                     2  ...                  23
# 833506                 2016                     4  ...                  24
# 833507                 2016                     2  ...                  29
# 833508                 2016                     1  ...                  30
# 833509                 2016                     4  ...                  13
#
#         pickup_datetimeDayofweek  pickup_datetimeDayofyear  \
# 0                              0                        74
# 1                              6                       164
# 2                              1                        19
# 3                              2                        97
# 4                              5                        86
# ...                          ...                       ...
# 833505                         1                        54
# 833506                         6                       115
# 833507                         0                        60
# 833508                         5                        30
# 833509                         2                       104
#
#         pickup_datetimeIs_month_end  pickup_datetimeIs_month_start  \
# 0                             False                          False
# 1                             False                          False
# 2                             False                          False
# 3                             False                          False
# 4                             False                          False
# ...                             ...                            ...
# 833505                        False                          False
# 833506                        False                          False
# 833507                         True                          False
# 833508                        False                          False
# 833509                        False                          False
#
#         pickup_datetimeIs_quarter_end  pickup_datetimeIs_quarter_start  \
# 0                               False                            False
# 1                               False                            False
# 2                               False                            False
# 3                               False                            False
# 4                               False                            False
# ...                               ...                              ...
# 833505                          False                            False
# 833506                          False                            False
# 833507                          False                            False
# 833508                          False                            False
# 833509                          False                            False
#
#         pickup_datetimeIs_year_end  pickup_datetimeIs_year_start  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# 4                            False                         False
# ...                            ...                           ...
# 833505                       False                         False
# 833506                       False                         False
# 833507                       False                         False
# 833508                       False                         False
# 833509                       False                         False
#
#         pickup_datetimeElapsed
# 0                   1457976295
# 1                   1465692215
# 2                   1453203324
# 3                   1459971151
# 4                   1458999055
# ...                        ...
# 833505              1456226477
# 833506              1461468915
# 833507              1456729381
# 833508              1454185326
# 833509              1460572187
#
# [833510 rows x 21 columns]

# %%
X_test
# Out:
#             id  vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# 0       469365          1                1        -73.988129        40.732029
# 1       547622          1                1        -73.964203        40.679993
# 2       190108          1                1        -73.997437        40.737583
# 3       335484          2                1        -73.956070        40.771900
# 4       249510          1                1        -73.970215        40.761475
# ...        ...        ...              ...               ...              ...
# 625129  470065          1                1        -74.003464        40.725105
# 625130  578498          1                1        -74.006363        40.743782
# 625131  401489          1                2        -73.972267        40.759865
# 625132  216305          1                1        -73.976501        40.733562
# 625133   97657          2                2        -73.981850        40.716881
#
#         dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 0              -73.990173         40.756680                   1
# 1              -73.959808         40.655403                   1
# 2              -73.986160         40.729523                   1
# 3              -73.986427         40.730469                   1
# 4              -73.961510         40.755890                   1
# ...                   ...               ...                 ...
# 625129         -74.001251         40.733643                   1
# 625130         -73.953407         40.782467                   1
# 625131         -73.876602         40.748665                   1
# 625132         -73.854263         40.891788                   1
# 625133         -73.969330         40.769379                   1
#
#         pickup_datetimeYear  pickup_datetimeMonth  ...  pickup_datetimeDay  \
# 0                      2016                     6  ...                  30
# 1                      2016                     6  ...                  30
# 2                      2016                     6  ...                  30
# 3                      2016                     6  ...                  30
# 4                      2016                     6  ...                  30
# ...                     ...                   ...  ...                 ...
# 625129                 2016                     1  ...                   1
# 625130                 2016                     1  ...                   1
# 625131                 2016                     1  ...                   1
# 625132                 2016                     1  ...                   1
# 625133                 2016                     1  ...                   1
#
#         pickup_datetimeDayofweek  pickup_datetimeDayofyear  \
# 0                              3                       182
# 1                              3                       182
# 2                              3                       182
# 3                              3                       182
# 4                              3                       182
# ...                          ...                       ...
# 625129                         4                         1
# 625130                         4                         1
# 625131                         4                         1
# 625132                         4                         1
# 625133                         4                         1
#
#         pickup_datetimeIs_month_end  pickup_datetimeIs_month_start  \
# 0                              True                          False
# 1                              True                          False
# 2                              True                          False
# 3                              True                          False
# 4                              True                          False
# ...                             ...                            ...
# 625129                        False                           True
# 625130                        False                           True
# 625131                        False                           True
# 625132                        False                           True
# 625133                        False                           True
#
#         pickup_datetimeIs_quarter_end  pickup_datetimeIs_quarter_start  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
# ...                               ...                              ...
# 625129                          False                             True
# 625130                          False                             True
# 625131                          False                             True
# 625132                          False                             True
# 625133                          False                             True
#
#         pickup_datetimeIs_year_end  pickup_datetimeIs_year_start  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# 4                            False                         False
# ...                            ...                           ...
# 625129                       False                          True
# 625130                       False                          True
# 625131                       False                          True
# 625132                       False                          True
# 625133                       False                          True
#
#         pickup_datetimeElapsed
# 0                   1467331198
# 1                   1467331193
# 2                   1467331187
# 3                   1467331181
# 4                   1467331173
# ...                        ...
# 625129              1451606572
# 625130              1451606512
# 625131              1451606484
# 625132              1451606428
# 625133              1451606422
#
# [625134 rows x 21 columns]

# %% [markdown]
# ## Random Forest

# %%
def rmse(x,y): return math.sqrt(((x-y)**2).mean())

def print_score(m):
    res = [rmse(m.predict(X_train), y_train), rmse(m.predict(X_valid), y_valid),
                m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m,'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
m = RandomForestRegressor(n_estimators=100,n_jobs=-1,oob_score=True)
# %time m.fit(X_train,y_train)
print_score(m)
# Out:
# CPU times: user 45min 50s, sys: 27 s, total: 46min 17s
# Wall time: 12min 49s
# [0.16945511982139552, 0.4521457147008209, 0.9550366876012534, 0.6807560110118979, 0.6733860996141081]

# %% [markdown]
# **overfitting, 94% on training set yet 66% on validation set**

# %% [markdown]
# ### Submit Test set

# %%
preds = m.predict(X_test)
preds
# Out:
# array([7.10932, 6.31243, 6.30431, ..., 7.22141, 7.76516, 7.10233])

# %% [markdown]
# **convert back from log by applying exponent**

# %%
preds_exp = np.exp(preds).astype('int')

# %%
preds_exp
# Out:
# array([1223,  551,  546, ..., 1368, 2357, 1214])

# %%
len(preds)
# Out:
# 625134

# %%
df_sub = pd.DataFrame({
    'id': df_test['id'].values,
    'trip_duration': preds_exp}).set_index('id')

# %%
df_sub.to_csv('subs/nyc001.csv')

# %%
df_test['id'].values
# Out:
# array(['id3004672', 'id3505355', 'id1217141', ..., 'id2568735', 'id1384355', 'id0621643'], dtype=object)

# %% [markdown]
# **score of 0.45496 in Kaggle around 50%, not great, but will score improve with feature engineering?**

# %% [markdown]
# ## GBM

# %% [markdown]
# ## XGBoost
