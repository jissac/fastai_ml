# %% [markdown]
# # Lesson 3 Notes: Large Datasets
# In this notebook, looking at Rossmann store sales prediction
# RFs allow us to understand our data more deeply than traditional ML techniques
# - for structured data - random forests
# - for unstructured data - deep learning
# - collaborative filtering - another ML model use case

# %% [markdown]
# ## Large Datasets
# - Usually, reading and writing to RAM is the bottle-neck
# - check datatypes before and use the smallest memory efficient dtype
# - dates are usually important, make sure dates don't overlap
#     - understand dates in training set, test set
# - %prun will show which process is taking the most time (profiling)

# %% [markdown]
# ### How to know if there's errors in your model
# - ML models are tricky, small error can cause mistakes without you knowing
# - ask "What do I know about the outputs?"
# - Need a good validation set.
# - Plot validation results against test set results - should follow the y=x line if it's a good validation set (only time to use test set before final modle tuned)

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
import os
sys.path.insert(0, "/Users/JI/Documents/Github/fastai/old/")
# print(sys.path)
import fastai
print(sys.modules['fastai'])
# Out:
# <module 'fastai' from '/Users/JI/Documents/Github/fastai/courses/ml1/fastai/__init__.py'>

# %%
from fastai.structured import *
import pandas as pd
import numpy as np
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %% [markdown]
# #### Load Rossmann data: Training set

# %%
types = {"Store": "uint16",
         "DayOfWeek": "uint8",
         "Sales": "uint16",
         "Customers": "uint16",
         "Open": "bool",
         "Promo": "bool",
         "StateHoliday":"object",
         "SchoolHoliday": "bool"}
# %time
df = pd.read_csv("./data/rossmann/train.csv",parse_dates=['Date'],dtype=types,
                 infer_datetime_format=True)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs

# %%
df.dtypes
# Out:
# Store                    uint16
# DayOfWeek                 uint8
# Date             datetime64[ns]
# Sales                    uint16
# Customers                uint16
# Open                       bool
# Promo                      bool
# StateHoliday             object
# SchoolHoliday              bool
# dtype: object

# %%
df.Promo.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03

# %%
# %time df.to_feather('/tmp/rossmann')
# Out:
# CPU times: user 116 ms, sys: 24.4 ms, total: 141 ms
# Wall time: 182 ms

# %%
# %time df.describe(include='all')
# Out:
# CPU times: user 274 ms, sys: 18 ms, total: 292 ms
# Wall time: 331 ms
#                Store     DayOfWeek                 Date         Sales  \
# count   1.017209e+06  1.017209e+06              1017209  1.017209e+06
# unique           NaN           NaN                  942           NaN
# top              NaN           NaN  2015-06-09 00:00:00           NaN
# freq             NaN           NaN                 1115           NaN
# first            NaN           NaN  2013-01-01 00:00:00           NaN
# last             NaN           NaN  2015-07-31 00:00:00           NaN
# mean    5.584297e+02  3.998341e+00                  NaN  5.773819e+03
# std     3.219087e+02  1.997391e+00                  NaN  3.849926e+03
# min     1.000000e+00  1.000000e+00                  NaN  0.000000e+00
# 25%     2.800000e+02  2.000000e+00                  NaN  3.727000e+03
# 50%     5.580000e+02  4.000000e+00                  NaN  5.744000e+03
# 75%     8.380000e+02  6.000000e+00                  NaN  7.856000e+03
# max     1.115000e+03  7.000000e+00                  NaN  4.155100e+04
#
#            Customers     Open    Promo StateHoliday SchoolHoliday
# count   1.017209e+06  1017209  1017209      1017209       1017209
# unique           NaN        2        2            4             2
# top              NaN     True    False            0         False
# freq             NaN   844392   629129       986159        835488
# first            NaN      NaN      NaN          NaN           NaN
# last             NaN      NaN      NaN          NaN           NaN
# mean    6.331459e+02      NaN      NaN          NaN           NaN
# std     4.644117e+02      NaN      NaN          NaN           NaN
# min     0.000000e+00      NaN      NaN          NaN           NaN
# 25%     4.050000e+02      NaN      NaN          NaN           NaN
# 50%     6.090000e+02      NaN      NaN          NaN           NaN
# 75%     8.370000e+02      NaN      NaN          NaN           NaN
# max     7.388000e+03      NaN      NaN          NaN           NaN

# %%
df.StateHoliday.unique()
# Out:
# array(['0', 'a', 'b', 'c'], dtype=object)

# %% [markdown]
# #### Test Set

# %%
types = {"Id":"uint16",
         "Store": "uint16",
         "DayOfWeek": "uint8",
         "Sales": "uint16",
         "Customers": "uint16",
         "Open": "object",
         "Promo": "bool",
         "StateHoliday":"object",
         "SchoolHoliday": "bool"}
df_test = pd.read_csv("./data/rossmann/test.csv",parse_dates=['Date'],dtype=types,
                 infer_datetime_format=True)
df_test.Open.fillna(False,inplace=True)
df_test.Open = df_test.Open.map({'False':False,'True':True})
df_test.Open = df_test.Open.astype(bool)

# %%
# %time df_test.describe(include='all')
# Out:
# CPU times: user 33.4 ms, sys: 2.14 ms, total: 35.5 ms
# Wall time: 50.4 ms
#                   Id         Store     DayOfWeek                 Date   Open  \
# count   41088.000000  41088.000000  41088.000000                41088  41088
# unique           NaN           NaN           NaN                   48      1
# top              NaN           NaN           NaN  2015-09-15 00:00:00   True
# freq             NaN           NaN           NaN                  856  41088
# first            NaN           NaN           NaN  2015-08-01 00:00:00    NaN
# last             NaN           NaN           NaN  2015-09-17 00:00:00    NaN
# mean    20544.500000    555.899533      3.979167                  NaN    NaN
# std     11861.228267    320.274496      2.015481                  NaN    NaN
# min         1.000000      1.000000      1.000000                  NaN    NaN
# 25%     10272.750000    279.750000      2.000000                  NaN    NaN
# 50%     20544.500000    553.500000      4.000000                  NaN    NaN
# 75%     30816.250000    832.250000      6.000000                  NaN    NaN
# max     41088.000000   1115.000000      7.000000                  NaN    NaN
#
#         Promo StateHoliday SchoolHoliday
# count   41088        41088         41088
# unique      2            2             2
# top     False            0         False
# freq    24824        40908         22866
# first     NaN          NaN           NaN
# last      NaN          NaN           NaN
# mean      NaN          NaN           NaN
# std       NaN          NaN           NaN
# min       NaN          NaN           NaN
# 25%       NaN          NaN           NaN
# 50%       NaN          NaN           NaN
# 75%       NaN          NaN           NaN
# max       NaN          NaN           NaN

# %%
df_test.dtypes, len(df_test)
# Out:
# (Id                       uint16
#  Store                    uint16
#  DayOfWeek                 uint8
#  Date             datetime64[ns]
#  Open                       bool
#  Promo                      bool
#  StateHoliday             object
#  SchoolHoliday              bool
#  dtype: object,
#  41088)

# %% [markdown]
# #### Cleaning

# %%
df.tail()
# Out:
#          Store  DayOfWeek       Date  Sales  Customers   Open  Promo  \
# 1017204   1111          2 2013-01-01      0          0  False  False
# 1017205   1112          2 2013-01-01      0          0  False  False
# 1017206   1113          2 2013-01-01      0          0  False  False
# 1017207   1114          2 2013-01-01      0          0  False  False
# 1017208   1115          2 2013-01-01      0          0  False  False
#
#         StateHoliday  SchoolHoliday
# 1017204            a           True
# 1017205            a           True
# 1017206            a           True
# 1017207            a           True
# 1017208            a           True

# %% [markdown]
# #### Check sales values to match evaluation metric
# https://gist.github.com/bshishov/5dc237f59f019b26145648e2124ca1c9
#
# - in this case they're using RMSPE, so no need to take the log of sales values. Will leave as # units

# %%
df.Sales
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1017204        0
# 1017205        0
# 1017206        0
# 1017207        0
# 1017208        0
# Name: Sales, Length: 1017209, dtype: uint16

# %% [markdown]
# #### Add datepart

# %%
# %time add_datepart(df,'Date')
# Out:
# CPU times: user 848 ms, sys: 152 ms, total: 1 s
# Wall time: 1.35 s

# %%
df.head()
# Out:
#    Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5   5263        555  True   True            0
# 1      2          5   6064        625  True   True            0
# 2      3          5   8314        821  True   True            0
# 3      4          5  13995       1498  True   True            0
# 4      5          5   4822        559  True   True            0
#
#    SchoolHoliday  Year  Month  ...  Day  Dayofweek  Dayofyear  Is_month_end  \
# 0           True  2015      7  ...   31          4        212          True
# 1           True  2015      7  ...   31          4        212          True
# 2           True  2015      7  ...   31          4        212          True
# 3           True  2015      7  ...   31          4        212          True
# 4           True  2015      7  ...   31          4        212          True
#
#    Is_month_start  Is_quarter_end  Is_quarter_start  Is_year_end  \
# 0           False           False             False        False
# 1           False           False             False        False
# 2           False           False             False        False
# 3           False           False             False        False
# 4           False           False             False        False
#
#    Is_year_start     Elapsed
# 0          False  1438300800
# 1          False  1438300800
# 2          False  1438300800
# 3          False  1438300800
# 4          False  1438300800
#
# [5 rows x 21 columns]

# %% [markdown]
# #### split raw df into train and val sets, val set contains most recent values

# %%
def split_vals(a,n):
    return a[:n].copy(),a[n:].copy()

# %%
n_valid = len(df_test)
n_train = len(df)-n_valid
training_set, val_set = split_vals(df,n_train)
training_set.shape, val_set.shape
# Out:
# ((976121, 21), (41088, 21))

# %% [markdown]
# #### Separate response variables in df and convert everything to numeric

# %%
# %time
X_train, y_train, _ = proc_df(training_set,y_fld='Sales')
X_val, y_val, _ = proc_df(val_set,y_fld='Sales')
# Out:
# CPU times: user 12 µs, sys: 1 µs, total: 13 µs
# Wall time: 35 µs

# %% [markdown]
# ### Models

# %%
EPSILON = 1e-10

def _error(actual: np.ndarray, predicted: np.ndarray):
    """ Simple error """
    return actual - predicted

def _percentage_error(actual: np.ndarray, predicted: np.ndarray):
    """
    Percentage error
    Note: result is NOT multiplied by 100
    """
    return _error(actual, predicted) / (actual + EPSILON)

def rmspe(actual: np.ndarray, predicted: np.ndarray):
    """
    Root Mean Squared Percentage Error
    Note: result is NOT multiplied by 100
    """
    return np.sqrt(np.mean(np.square(_percentage_error(actual, predicted))))

# %%
def print_score(m):
    res = [rmspe(y_train,m.predict(X_train)),rmspe(y_val,m.predict(X_val)),
           m.score(X_train,y_train),m.score(X_val,y_val)]
    if hasattr(m,'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
# set_rf_samples(100_000)
reset_rf_samples()
m = RandomForestRegressor(n_estimators=100,min_samples_leaf=10,n_jobs=4)
# %prun m.fit(X_train,y_train)
# Out:
#          127481 function calls (126254 primitive calls) in 291.382 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       422  290.214    0.688  290.214    0.688 {method 'acquire' of '_thread.lock' objects}
#     18/16    0.592    0.033    1.061    0.066 {built-in method numpy.array}
#         5    0.244    0.049    0.244    0.049 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.127    0.127    0.469    0.469 managers.py:834(_interleave)
#         4    0.098    0.024    0.098    0.024 {built-in method numpy.empty}
#         2    0.019    0.010    0.019    0.010 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.010    0.010  291.382  291.382 <string>:1(<module>)
#       500    0.010    0.000    0.032    0.000 inspect.py:2102(_signature_from_function)
#      6500    0.009    0.000    0.015    0.000 inspect.py:2452(__init__)
#       500    0.003    0.000    0.005    0.000 base.py:164(<listcomp>)
#       500    0.003    0.000    0.055    0.000 base.py:177(get_params)
#       500    0.003    0.000    0.049    0.000 base.py:150(_get_param_names)
#       500    0.003    0.000    0.006    0.000 inspect.py:2732(__init__)
#      6500    0.003    0.000    0.004    0.000 enum.py:267(__call__)
# 5470/5460    0.002    0.000    0.003    0.000 {built-in method builtins.hasattr}
#  1300/100    0.002    0.000    0.026    0.000 base.py:32(clone)
#      7000    0.002    0.000    0.003    0.000 inspect.py:2781(<genexpr>)
#     19000    0.002    0.000    0.002    0.000 inspect.py:2502(name)
#       500    0.002    0.000    0.036    0.000 inspect.py:2183(_signature_from_callable)
# 7785/7784    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#         1    0.002    0.002  290.168  290.168 parallel.py:894(retrieve)
#      9054    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#      6500    0.001    0.000    0.001    0.000 enum.py:517(__new__)
#       500    0.001    0.000    0.002    0.000 base.py:175(<listcomp>)
#       100    0.001    0.000    0.002    0.000 {method 'randint' of 'numpy.random.mtrand.RandomState' objects}
#      1200    0.001    0.000    0.002    0.000 copy.py:132(deepcopy)
#      9403    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#     12000    0.001    0.000    0.001    0.000 inspect.py:2514(kind)
#        98    0.001    0.000  290.164    2.961 threading.py:263(wait)
#       200    0.001    0.000    0.024    0.000 base.py:200(set_params)
#       600    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#      6500    0.001    0.000    0.001    0.000 {method 'isidentifier' of 'str' objects}
#       107    0.001    0.000  290.165    2.712 threading.py:533(wait)
#       500    0.001    0.000    0.001    0.000 inspect.py:485(unwrap)
#       100    0.001    0.000    0.027    0.000 base.py:21(_set_random_states)
#      6505    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       100    0.000    0.000    0.067    0.001 base.py:120(_make_estimator)
#       496    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       100    0.000    0.000  290.166    2.902 pool.py:637(get)
#       109    0.000    0.000    0.001    0.000 _dtype.py:333(_name_get)
#       100    0.000    0.000  290.165    2.902 pool.py:634(wait)
#       500    0.000    0.000    0.037    0.000 inspect.py:2811(from_callable)
#      1000    0.000    0.000    0.000    0.000 inspect.py:159(isfunction)
#       500    0.000    0.000    0.037    0.000 inspect.py:3063(signature)
#      1140    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#       109    0.000    0.000    0.001    0.000 _dtype.py:319(_name_includes_bit_suffix)
#       100    0.000    0.000    0.000    0.000 base.py:127(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 series.py:515(array)
#      1100    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#       112    0.000    0.000    0.000    0.000 abc.py:180(__instancecheck__)
#       100    0.000    0.000    0.000    0.000 pool.py:627(ready)
#       101    0.000    0.000    0.001    0.000 validation.py:763(check_random_state)
#      1100    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#      1700    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       100    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       100    0.000    0.000    0.000    0.000 tree.py:1091(__init__)
#   737/724    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       500    0.000    0.000    0.000    0.000 inspect.py:505(_is_wrapper)
#       136    0.000    0.000    0.000    0.000 threading.py:239(__enter__)
#        98    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#       212    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         7    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       101    0.000    0.000    0.000    0.000 numerictypes.py:365(issubdtype)
#       202    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#       136    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#       101    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#      1200    0.000    0.000    0.000    0.000 copy.py:190(_deepcopy_atomic)
#       100    0.000    0.000    0.000    0.000 tree.py:81(__init__)
#       500    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       124    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#         5    0.000    0.000    0.244    0.049 blocks.py:225(get_values)
#         1    0.000    0.000    0.067    0.067 forest.py:315(<listcomp>)
#        36    0.000    0.000    0.000    0.000 common.py:1708(_is_dtype_type)
#       117    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        17    0.000    0.000    0.000    0.000 queue.py:115(put)
#       136    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        27    0.000    0.000    0.000    0.000 threading.py:215(__init__)
#       500    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#        98    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#         2    0.000    0.000    1.079    0.539 validation.py:332(check_array)
#         9    0.000    0.000    0.002    0.000 parallel.py:773(dispatch_one_batch)
#       100    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       500    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.001    0.001 pool.py:225(_repopulate_pool)
#       118    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#       500    0.000    0.000    0.000    0.000 inspect.py:2817(parameters)
#         1    0.000    0.000  291.371  291.371 forest.py:217(fit)
#       501    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.052    0.052 _parallel_backends.py:240(terminate)
#         1    0.000    0.000  290.222  290.222 parallel.py:942(__call__)
#         3    0.000    0.000    0.001    0.000 series.py:183(__init__)
#         7    0.000    0.000    0.000    0.000 threading.py:757(__init__)
#         1    0.000    0.000  291.382  291.382 {built-in method builtins.exec}
#       107    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       136    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.020    0.010 validation.py:36(_assert_all_finite)
#        15    0.000    0.000    0.000    0.000 common.py:222(is_object_dtype)
#         1    0.000    0.000    0.001    0.001 pool.py:153(__init__)
#         8    0.000    0.000    0.002    0.000 parallel.py:736(_dispatch)
#       109    0.000    0.000    0.000    0.000 _dtype.py:36(_kind_name)
#         3    0.000    0.000    0.000    0.000 algorithms.py:1436(_get_take_nd_function)
#         3    0.000    0.000    0.000    0.000 algorithms.py:1565(take_nd)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.eval}
#         7    0.000    0.000    0.001    0.000 threading.py:828(start)
#        11    0.000    0.000    0.000    0.000 queue.py:147(get)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#        26    0.000    0.000    0.000    0.000 threading.py:334(notify)
#        70    0.000    0.000    0.000    0.000 generic.py:10(_check)
#         1    0.000    0.000    0.052    0.052 pool.py:561(_terminate_pool)
#        11    0.000    0.000    0.000    0.000 _internal.py:830(npy_ctypes_check)
#       115    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         4    0.000    0.000    0.052    0.013 threading.py:1062(_wait_for_tstate_lock)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         3    0.000    0.000    0.001    0.000 generic.py:5519(dtypes)
#         3    0.000    0.000    0.000    0.000 blocks.py:2981(get_block_type)
#        20    0.000    0.000    0.000    0.000 dtypes.py:75(find)
#        17    0.000    0.000    0.000    0.000 common.py:1565(is_extension_array_dtype)
#         3    0.000    0.000    0.000    0.000 construction.py:388(sanitize_array)
#         3    0.000    0.000    0.000    0.000 construction.py:506(_try_cast)
#         8    0.000    0.000    0.000    0.000 generic.py:5257(__getattr__)
#         8    0.000    0.000    0.000    0.000 pool.py:349(apply_async)
#         4    0.000    0.000    0.000    0.000 pool.py:783(Process)
#         3    0.000    0.000    0.000    0.000 cast.py:1209(maybe_cast_to_datetime)
#        15    0.000    0.000    0.000    0.000 threading.py:498(__init__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         4    0.000    0.000    0.000    0.000 queue.py:27(__init__)
#         9    0.000    0.000    0.000    0.000 common.py:1844(pandas_dtype)
#         8    0.000    0.000    0.000    0.000 blocks.py:247(mgr_locs)
#         8    0.000    0.000    0.000    0.000 pool.py:619(__init__)
#         8    0.000    0.000    0.000    0.000 functools.py:44(update_wrapper)
#         3    0.000    0.000    0.052    0.017 threading.py:1024(join)
#         1    0.000    0.000    0.000    0.000 cast.py:1342(find_common_type)
#        21    0.000    0.000    0.000    0.000 threading.py:1230(current_thread)
#         4    0.000    0.000    0.000    0.000 __init__.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 parallel.py:616(__init__)
#         3    0.000    0.000    0.001    0.000 managers.py:1467(__init__)
#         8    0.000    0.000    0.000    0.000 forest.py:327(<genexpr>)
#         3    0.000    0.000    0.000    0.000 threading.py:966(_stop)
#        31    0.000    0.000    0.000    0.000 common.py:208(<lambda>)
#        31    0.000    0.000    0.000    0.000 common.py:206(classes)
#         3    0.000    0.000    0.000    0.000 cast.py:1088(maybe_castable)
#         2    0.000    0.000    0.000    0.000 managers.py:163(shape)
#         8    0.000    0.000    0.002    0.000 _parallel_backends.py:251(apply_async)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#        15    0.000    0.000    0.000    0.000 base.py:247(is_dtype)
#         3    0.000    0.000    0.000    0.000 managers.py:248(get_dtypes)
#         8    0.000    0.000    0.000    0.000 parallel.py:240(__init__)
#         8    0.000    0.000    0.000    0.000 parallel.py:295(delayed)
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:38(_remove)
#         1    0.000    0.000    0.000    0.000 util.py:151(__init__)
#         4    0.000    0.000    0.000    0.000 generic.py:5276(__setattr__)
#         4    0.000    0.000    0.001    0.000 __init__.py:43(start)
#         7    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         2    0.000    0.000    0.000    0.000 warnings.py:449(__enter__)
#         4    0.000    0.000    0.000    0.000 common.py:252(is_sparse)
#         3    0.000    0.000    0.001    0.000 blocks.py:3027(make_block)
#         4    0.000    0.000    0.000    0.000 weakref.py:354(__init__)
#         2    0.000    0.000    0.000    0.000 warnings.py:468(__exit__)
#        17    0.000    0.000    0.000    0.000 queue.py:206(_put)
#         3    0.000    0.000    0.000    0.000 blocks.py:118(__init__)
#         1    0.000    0.000    0.052    0.052 util.py:167(__call__)
#         6    0.000    0.000    0.000    0.000 common.py:403(is_datetime64tz_dtype)
#        20    0.000    0.000    0.000    0.000 blocks.py:339(dtype)
#         2    0.000    0.000    0.000    0.000 warnings.py:159(_add_filter)
#         7    0.000    0.000    0.000    0.000 threading.py:727(_newname)
#        11    0.000    0.000    0.000    0.000 base.py:615(__len__)
#         3    0.000    0.000    0.000    0.000 generic.py:190(__init__)
#         8    0.000    0.000    0.000    0.000 _parallel_backends.py:125(get_nested_backend)
#         1    0.000    0.000    0.019    0.019 extmath.py:663(_safe_accumulator_op)
#         1    0.000    0.000    0.000    0.000 base.py:101(_validate_estimator)
#         2    0.000    0.000    0.000    0.000 version.py:307(parse)
#         1    0.000    0.000    0.019    0.019 fromnumeric.py:73(_wrapreduction)
#         7    0.000    0.000    0.000    0.000 common.py:372(is_datetime64_dtype)
#         5    0.000    0.000    0.000    0.000 common.py:775(is_integer_dtype)
#         3    0.000    0.000    0.000    0.000 managers.py:249(<listcomp>)
#         1    0.000    0.000    0.469    0.469 managers.py:798(as_array)
#         1    0.000    0.000    0.000    0.000 pool.py:797(_help_stuff_finish)
#         4    0.000    0.000    0.000    0.000 common.py:1401(is_float_dtype)
#         1    0.000    0.000    0.000    0.000 parallel.py:81(get_active_backend)
#         1    0.000    0.000    0.000    0.000 logger.py:23(_squeeze_time)
#         1    0.000    0.000    0.000    0.000 fixes.py:207(_joblib_parallel_args)
#        21    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         2    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#         3    0.000    0.000    0.019    0.006 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 base.py:3897(__contains__)
#         3    0.000    0.000    0.000    0.000 base.py:5393(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 numpy_.py:138(__init__)
#         6    0.000    0.000    0.000    0.000 managers.py:165(<genexpr>)
#         1    0.000    0.000    0.000    0.000 logger.py:39(short_format_time)
#         8    0.000    0.000    0.001    0.000 _parallel_backends.py:401(_get_pool)
#        10    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 weakref.py:356(remove)
#       7/6    0.000    0.000    1.057    0.176 _asarray.py:16(asarray)
#         1    0.000    0.000    0.019    0.019 fromnumeric.py:2092(sum)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         4    0.000    0.000    0.000    0.000 generic.py:491(_info_axis)
#         1    0.000    0.000    0.469    0.469 generic.py:5412(values)
#         3    0.000    0.000    0.000    0.000 blocks.py:251(mgr_locs)
#         3    0.000    0.000    0.000    0.000 series.py:376(_set_axis)
#         1    0.000    0.000    0.000    0.000 disk.py:41(memstr_to_bytes)
#        10    0.000    0.000    0.000    0.000 _parallel_backends.py:37(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 functools.py:74(wraps)
#         2    0.000    0.000    0.000    0.000 warnings.py:428(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:85(__exit__)
#         8    0.000    0.000    0.000    0.000 queue.py:210(_get)
#         1    0.000    0.000    0.019    0.019 <__array_function__ internals>:2(sum)
#         3    0.000    0.000    0.000    0.000 common.py:339(is_categorical)
#         6    0.000    0.000    0.000    0.000 construction.py:337(extract_array)
#         3    0.000    0.000    0.000    0.000 construction.py:570(is_empty_data)
#         3    0.000    0.000    0.000    0.000 generic.py:255(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:219(array_values)
#         3    0.000    0.000    0.000    0.000 blocks.py:2591(__init__)
#         3    0.000    0.000    0.000    0.000 series.py:428(name)
#         1    0.000    0.000    0.000    0.000 pool.py:531(close)
#         1    0.000    0.000    0.052    0.052 pool.py:537(terminate)
#         2    0.000    0.000    0.000    0.000 _config.py:13(get_config)
#         2    0.000    0.000    0.000    0.000 validation.py:131(_num_samples)
#         8    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        10    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 warnings.py:143(simplefilter)
#         1    0.000    0.000    0.000    0.000 contextlib.py:59(__init__)
#        11    0.000    0.000    0.000    0.000 queue.py:202(_qsize)
#         1    0.000    0.000    0.000    0.000 shape_base.py:25(atleast_1d)
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.469    0.469 {pandas._libs.lib.values_from_object}
#         3    0.000    0.000    0.000    0.000 dtypes.py:917(is_dtype)
#         3    0.000    0.000    0.000    0.000 dtypes.py:1124(is_dtype)
#         5    0.000    0.000    0.000    0.000 common.py:216(<lambda>)
#         3    0.000    0.000    0.000    0.000 cast.py:1483(construct_1d_ndarray_preserving_na)
#         3    0.000    0.000    0.000    0.000 series.py:432(name)
#         8    0.000    0.000    0.000    0.000 parallel.py:326(__init__)
#         1    0.000    0.000    0.000    0.000 parallel.py:707(_initialize_backend)
#         7    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 weakref.py:406(__setitem__)
#         7    0.000    0.000    0.000    0.000 threading.py:1136(daemon)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:55(_wrapfunc)
#         9    0.000    0.000    0.000    0.000 inference.py:358(is_hashable)
#         4    0.000    0.000    0.000    0.000 common.py:441(is_timedelta64_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:506(is_interval_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:542(is_categorical_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1435(is_bool_dtype)
#         6    0.000    0.000    0.000    0.000 cast.py:1370(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:1679(is_object)
#         1    0.000    0.000    0.000    0.000 base.py:3949(_can_hold_identifiers_and_holds_name)
#         1    0.000    0.000    0.000    0.000 numpy_.py:42(__init__)
#         1    0.000    0.000    0.469    0.469 generic.py:1908(__array__)
#         1    0.000    0.000    0.000    0.000 generic.py:5344(f)
#         2    0.000    0.000    0.000    0.000 range.py:675(__len__)
#         3    0.000    0.000    0.000    0.000 blocks.py:129(_check_ndim)
#         1    0.000    0.000    0.000    0.000 managers.py:1855(_interleaved_dtype)
#         1    0.000    0.000    0.000    0.000 series.py:707(__array__)
#         1    0.000    0.000    0.000    0.000 pool.py:791(_setup_queues)
#        24    0.000    0.000    0.000    0.000 parallel.py:258(__len__)
#         1    0.000    0.000    0.052    0.052 parallel.py:732(_terminate_backend)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:281(__init__)
#         8    0.000    0.000    0.000    0.000 _parallel_backends.py:603(__init__)
#         2    0.000    0.000    0.000    0.000 validation.py:325(_ensure_no_complex_data)
#         7    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#        11    0.000    0.000    0.000    0.000 util.py:48(debug)
#         2    0.000    0.000    0.000    0.000 version.py:312(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 inference.py:96(is_iterator)
#         1    0.000    0.000    0.000    0.000 common.py:685(is_dtype_equal)
#         3    0.000    0.000    0.000    0.000 common.py:1672(_get_dtype)
#         2    0.000    0.000    0.000    0.000 cast.py:1376(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:5341(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 managers.py:199(_is_single_block)
#         1    0.000    0.000    0.000    0.000 managers.py:1872(<listcomp>)
#         3    0.000    0.000    0.000    0.000 series.py:403(_set_subtyp)
#         1    0.000    0.000    0.001    0.001 pool.py:788(__init__)
#         3    0.000    0.000    0.000    0.000 base.py:1192(isspmatrix)
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:157(helper)
#         1    0.000    0.000    0.000    0.000 threading.py:74(RLock)
#         1    0.000    0.000    0.000    0.000 threading.py:357(notify_all)
#         4    0.000    0.000    0.000    0.000 threading.py:1076(name)
#         4    0.000    0.000    0.000    0.000 threading.py:1087(name)
#         7    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#         4    0.000    0.000    0.000    0.000 queue.py:199(_init)
#         1    0.000    0.000    0.000    0.000 version.py:57(__le__)
#         2    0.000    0.000    0.000    0.000 version.py:302(__init__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:202(reshape)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(reshape)
#         1    0.000    0.000    0.000    0.000 common.py:1614(is_complex_dtype)
#         2    0.000    0.000    0.000    0.000 cast.py:1367(<genexpr>)
#         2    0.000    0.000    0.000    0.000 cast.py:1374(<genexpr>)
#         2    0.000    0.000    0.000    0.000 cast.py:1381(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:5293(ensure_index)
#         1    0.000    0.000    0.000    0.000 numpy_.py:183(__array__)
#         1    0.000    0.000    0.000    0.000 generic.py:5331(_protect_consolidate)
#         1    0.000    0.000    0.000    0.000 managers.py:660(is_mixed_type)
#         1    0.000    0.000    0.000    0.000 managers.py:927(consolidate)
#         1    0.000    0.000    0.000    0.000 managers.py:943(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         3    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:79(__enter__)
#         2    0.000    0.000    0.000    0.000 context.py:232(get_context)
#         1    0.000    0.000    0.000    0.000 util.py:44(sub_debug)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 version.py:331(_cmp)
#         1    0.000    0.000    0.000    0.000 shape_base.py:21(_atleast_1d_dispatcher)
#         1    0.000    0.000    0.004    0.004 _asarray.py:141(ascontiguousarray)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#         5    0.000    0.000    0.000    0.000 common.py:211(classes_and_not_datetimelike)
#         3    0.000    0.000    0.000    0.000 common.py:472(is_period_dtype)
#         2    0.000    0.000    0.000    0.000 managers.py:167(ndim)
#         2    0.000    0.000    0.000    0.000 managers.py:647(is_consolidated)
#         8    0.000    0.000    0.000    0.000 parallel.py:305(delayed_function)
#         2    0.000    0.000    0.000    0.000 parallel.py:838(_print)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:81(start_call)
#         9    0.000    0.000    0.000    0.000 _parallel_backends.py:90(compute_batch_size)
#         2    0.000    0.000    0.000    0.000 _parallel_backends.py:138(retrieval_context)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:228(effective_n_jobs)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:390(configure)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 _asarray.py:88(asanyarray)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:197(_reshape_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:1520(_block)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:84(stop_call)
#         1    0.000    0.000    0.000    0.000 forest.py:349(_validate_y_class_weight)

# %%
print_score(m)
# Out:
# [1042345421.5645587, 2319965865.481266, 0.9638837404090848, 0.9553316424467648]
